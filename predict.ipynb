# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
weather=pd.read_csv("Honavar.csv",index_col="date")

# %%
weather
# Out:
#                            Unnamed: 0  temperature_2m  relative_humidity_2m  \
# date
# 2010-01-01 00:00:00+00:00           0       23.106500             92.686380
# 2010-01-01 01:00:00+00:00           1       23.106500             91.841064
# 2010-01-01 02:00:00+00:00           2       23.306500             90.460890
# 2010-01-01 03:00:00+00:00           3       25.006500             84.219730
# 2010-01-01 04:00:00+00:00           4       26.606500             77.303190
# ...                               ...             ...                   ...
# 2024-02-20 19:00:00+00:00      123931       23.429500             91.860054
# 2024-02-20 20:00:00+00:00      123932       21.829498             98.182910
# 2024-02-20 21:00:00+00:00      123933       20.779500             99.386210
# 2024-02-20 22:00:00+00:00      123934       20.529500             98.468830
# 2024-02-20 23:00:00+00:00      123935       20.479500             96.358440
#
#                            dew_point_2m  apparent_temperature  precipitation  \
# date
# 2010-01-01 00:00:00+00:00     21.856500             27.016226            0.0
# 2010-01-01 01:00:00+00:00     21.706501             26.744470            0.0
# 2010-01-01 02:00:00+00:00     21.656500             26.685429            0.0
# 2010-01-01 03:00:00+00:00     22.156500             28.647530            0.0
# 2010-01-01 04:00:00+00:00     22.306500             30.285740            0.0
# ...                                 ...                   ...            ...
# 2024-02-20 19:00:00+00:00     22.029500             27.991505            0.0
# 2024-02-20 20:00:00+00:00     21.529500             25.863148            0.0
# 2024-02-20 21:00:00+00:00     20.679500             24.228530            0.0
# 2024-02-20 22:00:00+00:00     20.279500             23.433128            0.0
# 2024-02-20 23:00:00+00:00     19.879501             23.239012            0.0
#
#                            rain  snowfall  snow_depth  pressure_msl  \
# date
# 2010-01-01 00:00:00+00:00   0.0       0.0         0.0        1009.7
# 2010-01-01 01:00:00+00:00   0.0       0.0         0.0        1010.2
# 2010-01-01 02:00:00+00:00   0.0       0.0         0.0        1010.8
# 2010-01-01 03:00:00+00:00   0.0       0.0         0.0        1011.6
# 2010-01-01 04:00:00+00:00   0.0       0.0         0.0        1012.2
# ...                         ...       ...         ...           ...
# 2024-02-20 19:00:00+00:00   0.0       0.0         0.0        1012.1
# 2024-02-20 20:00:00+00:00   0.0       0.0         0.0        1011.4
# 2024-02-20 21:00:00+00:00   0.0       0.0         0.0        1010.7
# 2024-02-20 22:00:00+00:00   0.0       0.0         0.0        1010.5
# 2024-02-20 23:00:00+00:00   0.0       0.0         0.0        1010.7
#
#                            surface_pressure  cloud_cover  cloud_cover_low  \
# date
# 2010-01-01 00:00:00+00:00        1007.95520     0.000000              0.0
# 2010-01-01 01:00:00+00:00        1008.45435     0.600000              0.0
# 2010-01-01 02:00:00+00:00        1009.05460     0.900000              1.0
# 2010-01-01 03:00:00+00:00        1009.86290     0.000000              0.0
# 2010-01-01 04:00:00+00:00        1010.47144     0.000000              0.0
# ...                                     ...          ...              ...
# 2024-02-20 19:00:00+00:00        1010.35297    22.800001              0.0
# 2024-02-20 20:00:00+00:00        1009.64470    45.600002             19.0
# 2024-02-20 21:00:00+00:00        1008.93990   100.000000            100.0
# 2024-02-20 22:00:00+00:00        1008.73870    32.400000              5.0
# 2024-02-20 23:00:00+00:00        1008.93800    15.900001              0.0
#
#                            cloud_cover_mid  cloud_cover_high  wind_speed_10m  \
# date
# 2010-01-01 00:00:00+00:00              0.0               0.0        6.409617
# 2010-01-01 01:00:00+00:00              1.0               0.0        7.704336
# 2010-01-01 02:00:00+00:00              0.0               0.0        9.290511
# 2010-01-01 03:00:00+00:00              0.0               0.0        9.387651
# 2010-01-01 04:00:00+00:00              0.0               0.0        9.693296
# ...                                    ...               ...             ...
# 2024-02-20 19:00:00+00:00              0.0              76.0        2.595997
# 2024-02-20 20:00:00+00:00              0.0              95.0        4.334974
# 2024-02-20 21:00:00+00:00              0.0              96.0        5.241679
# 2024-02-20 22:00:00+00:00              0.0              93.0        7.568566
# 2024-02-20 23:00:00+00:00              0.0              53.0        7.172949
#
#                            wind_speed_100m  wind_direction_10m  \
# date
# 2010-01-01 00:00:00+00:00        11.435313           51.842735
# 2010-01-01 01:00:00+00:00        13.708390           52.594578
# 2010-01-01 02:00:00+00:00        15.946010           54.462240
# 2010-01-01 03:00:00+00:00        15.941944           57.528828
# 2010-01-01 04:00:00+00:00        14.345898           68.198530
# ...                                    ...                 ...
# 2024-02-20 19:00:00+00:00         9.000000           56.309914
# 2024-02-20 20:00:00+00:00         3.600000           94.763560
# 2024-02-20 21:00:00+00:00         2.902413          105.945465
# 2024-02-20 22:00:00+00:00         7.491114          115.346140
# 2024-02-20 23:00:00+00:00         8.089994          107.525660
#
#                            wind_direction_100m  wind_gusts_10m
# date
# 2010-01-01 00:00:00+00:00            61.821507       15.480000
# 2010-01-01 01:00:00+00:00            60.068577       16.919998
# 2010-01-01 02:00:00+00:00            61.699340       18.359999
# 2010-01-01 03:00:00+00:00            64.592320       20.519999
# 2010-01-01 04:00:00+00:00            72.474340       20.880001
# ...                                        ...             ...
# 2024-02-20 19:00:00+00:00           343.739720        7.559999
# 2024-02-20 20:00:00+00:00            36.869990        7.559999
# 2024-02-20 21:00:00+00:00            97.124920        9.720000
# 2024-02-20 22:00:00+00:00           144.782320       12.959999
# 2024-02-20 23:00:00+00:00           147.724380       14.040000
#
# [123936 rows x 20 columns]

# %%
valid_columns = weather.columns[weather.isnull().mean() < 0.5]

# %%
valid_columns
# Out:
# Index(['Unnamed: 0', 'temperature_2m', 'relative_humidity_2m', 'dew_point_2m',
#        'apparent_temperature', 'precipitation', 'rain', 'snowfall',
#        'snow_depth', 'pressure_msl', 'surface_pressure', 'cloud_cover',
#        'cloud_cover_low', 'cloud_cover_mid', 'cloud_cover_high',
#        'wind_speed_10m', 'wind_speed_100m', 'wind_direction_10m',
#        'wind_direction_100m', 'wind_gusts_10m'],
#       dtype='object')

# %%
weather.dtypes
# Out:
# Unnamed: 0                int64
# temperature_2m          float64
# relative_humidity_2m    float64
# dew_point_2m            float64
# apparent_temperature    float64
# precipitation           float64
# rain                    float64
# snowfall                float64
# snow_depth              float64
# pressure_msl            float64
# surface_pressure        float64
# cloud_cover             float64
# cloud_cover_low         float64
# cloud_cover_mid         float64
# cloud_cover_high        float64
# wind_speed_10m          float64
# wind_speed_100m         float64
# wind_direction_10m      float64
# wind_direction_100m     float64
# wind_gusts_10m          float64
# dtype: object

# %%
weather.index
# Out:
# Index(['2010-01-01 00:00:00+00:00', '2010-01-01 01:00:00+00:00',
#        '2010-01-01 02:00:00+00:00', '2010-01-01 03:00:00+00:00',
#        '2010-01-01 04:00:00+00:00', '2010-01-01 05:00:00+00:00',
#        '2010-01-01 06:00:00+00:00', '2010-01-01 07:00:00+00:00',
#        '2010-01-01 08:00:00+00:00', '2010-01-01 09:00:00+00:00',
#        ...
#        '2024-02-20 14:00:00+00:00', '2024-02-20 15:00:00+00:00',
#        '2024-02-20 16:00:00+00:00', '2024-02-20 17:00:00+00:00',
#        '2024-02-20 18:00:00+00:00', '2024-02-20 19:00:00+00:00',
#        '2024-02-20 20:00:00+00:00', '2024-02-20 21:00:00+00:00',
#        '2024-02-20 22:00:00+00:00', '2024-02-20 23:00:00+00:00'],
#       dtype='object', name='date', length=123936)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# date
# 2010    8760
# 2011    8760
# 2012    8784
# 2013    8760
# 2014    8760
# 2015    8760
# 2016    8784
# 2017    8760
# 2018    8760
# 2019    8760
# 2020    8784
# 2021    8760
# 2022    8760
# 2023    8760
# 2024    1224
# Name: count, dtype: int64

# %%
weather["temperature_2m"].plot()
# Out:
# <Axes: xlabel='date'>
